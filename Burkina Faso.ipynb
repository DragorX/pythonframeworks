# %%
# %%HTML
#
# <html lang="ru">
#
# <head>
#
# 	<meta charset="utf-8">
#
# 	<title>Burkina Faso</title>
#     <h1>Burkina Faso</h1>
# </head>
# <body>
#     <h3><a href="https://goo.gl/maps/NJFdUtbSy1pnuk958">Area</a></h3>
#     <b> Burkina Faso </b> is a landlocked country in West Africa <br> that covers an area of around 274,200 square kilometres (105,900 sq mi)<br> and issurrounded by Mali, Niger; Benin, Togo, Ghana and Ivory Coast.
#
#
#     <h3>Ethnic groups</h3>
#     <ul><li>52% <a href="/wiki/Mossi_people" title="Mossi people">Mossi</a></li><li>8.4% <a href="/wiki/Fula_people" title="Fula people">Fula</a></li><li>2.4% <a href="/wiki/Lobi_people" title="Lobi people">Lobi</a></li><li>4.9% <a href="/wiki/Bobo_people" title="Bobo people">Bobo</a></li><li>0.8% <a href="/wiki/Dyula_people" title="Dyula people">Dioula</a></li><li>4.5% <a href="/wiki/Senufo_people" title="Senufo people">Senufo</a></li><li>4.6% <a href="/wiki/Gurunsi" class="mw-redirect" title="Gurunsi">Gurunsi</a></li><li>7% <a href="/wiki/Gurma_people" title="Gurma people">Gurma</a></li><li>1.9% <a href="/wiki/Tuareg_people" title="Tuareg people">Tuareg</a></li></ul>
#     <h3>Government</h3>
#     <a href="https://en.wikipedia.org/wiki/Roch_Marc_Christian_Kabor%C3%A9">Roch Marc Christian Kaboré</a> (born 25 April 1957) is a Burkinabé politician<br> and banker and the President of Burkina Faso, in office since 2015.<br> Previously he served as the Prime Minister of Burkina Faso between 1994 and 1996<br> and President of the National Assembly of Burkina Faso from 2002 to 2012
#     <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/a/a2/Roch_Marc_Christian_Kabor%C3%A9_MSC_2018_%28cropped%29.jpg/330px-Roch_Marc_Christian_Kabor%C3%A9_MSC_2018_%28cropped%29.jpg">
#     <h2><span class="mw-headline" id="Latest_election">Latest election</span><span class="mw-editsection"><span class="mw-editsection-bracket"></span></span></h2>
# <div role="note" class="hatnote navigation-not-searchable">Main article: <a href="/wiki/2015_Burkinab%C3%A9_general_election" title="2015 Burkinabé general election">2015 Burkinabé general election</a></div>
# <table class="wikitable" style="text-align:right">
# <tbody><tr>
# <th>Candidate
# </th>
# <th>Party
# </th>
# <th>Votes
# </th>
# <th>%
# </th></tr>
# <tr>
# <td align="left"><a href="/wiki/Roch_Marc_Christian_Kabor%C3%A9" title="Roch Marc Christian Kaboré">Roch Marc Christian Kaboré</a></td>
# <td align="left"><a href="/wiki/People%27s_Movement_for_Progress" title="People&#39;s Movement for Progress">People's Movement for Progress</a></td>
# <td>1,668,169</td>
# <td>53.49
# </td></tr>
# <tr>
# <td align="left"><a href="/wiki/Z%C3%A9phirin_Diabr%C3%A9" title="Zéphirin Diabré">Zéphirin Diabré</a></td>
# <td align="left"><a href="/wiki/Union_for_Progress_and_Reform" title="Union for Progress and Reform">Union for Progress and Reform</a></td>
# <td>924,811</td>
# <td>29.65
# </td></tr>
# <tr>
# <td>15,266</td>
# <td>0.49
# </td></tr>
# <tr>
# <td align="left"><a href="/w/index.php?title=Boukar%C3%A9_Ou%C3%A9draogo&amp;action=edit&amp;redlink=1" class="new" title="Boukaré Ouédraogo (page does not exist)">Boukaré Ouédraogo</a></td>
# <td align="left">Independent</td>
# <td>15,007</td>
# <td>0.48
# </td></tr>
# <tr>
# <td align="left"><a href="/w/index.php?title=Fran%C3%A7oise_To%C3%A9&amp;action=edit&amp;redlink=1" class="new" title="Françoise Toé (page does not exist)">Françoise Toé</a></td>
# <td align="left">Independent</td>
# <td>8,111</td>
# <td>0.26
# </td></tr>
# <tr>
# <td align="left" colspan="2">Invalid/blank votes</td>
# <td>191,293</td>
# <td>–
# </td></tr>
# <tr>
# <td align="left" colspan="2"><b>Total</b></td>
# <td><b>3,309,988</b></td>
# <td><b>100</b>
# </td></tr>
# <tr>
# <td align="left" colspan="2">Registered voters/turnout</td>
# <td>5,517,015</td>
# <td>60.00
# </td></tr>
# <tr>
# <td align="left" colspan="4">Source: <a rel="nofollow" class="external text" href="http://www.ceni.bf/sites/default/files/Resultat%20des%20%C3%A9lections%202015.pdf">CENI</a>
# </td></tr></tbody></table>
#     <h3>Flag</h3>
#     <div class="flag">
#         <svg version="1.0" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="900" height="600">
#         <rect width="900" height="600" fill="#009e49"/>
#         <rect width="900" height="300" fill="#ef2b2d"/>
#         <g transform="translate(450,300)" fill="#fcd116">
#             <g id="c">
#                 <path id="t" d="M 0,-100 V 0 H 50" transform="rotate(18 0,-100)"/>
#                 <use xlink:href="#t" transform="scale(-1,1)"/>
#             </g>
#             <use xlink:href="#c" transform="rotate(72)"/>
#             <use xlink:href="#c" transform="rotate(144)"/>
#             <use xlink:href="#c" transform="rotate(216)"/>
#             <use xlink:href="#c" transform="rotate(288)"/>
#         </g>
#         </svg>
#     </div>
#     <style>
#         .flag{
#             width:900px;
#             height:600px;
#             color:rgb(0, 0, 0);
#             border:4px double brown;
#             background: #eee;
#             padding: 20px;
#         }
#         </style>
# </body>
# </html>
# Out:
# <html lang="ru">
#
# <head>
#
# 	<meta charset="utf-8">
#
# 	<title>Burkina Faso</title>
#     <h1>Burkina Faso</h1>
# </head>
# <body>
#     <h3><a href="https://goo.gl/maps/NJFdUtbSy1pnuk958">Area</a></h3>
#     <b> Burkina Faso </b> is a landlocked country in West Africa <br> that covers an area of around 274,200 square kilometres (105,900 sq mi)<br> and issurrounded by Mali, Niger; Benin, Togo, Ghana and Ivory Coast.
#     <h3>Population</h3>
#     <i>The July 2019</i> population estimate by the United Nations was <ins>20,321,378</ins>.
#     <h3>Officia language</h3>
#     <ul>
#         <li>French</li>
#         <li>Moore</li>
#         <li>Fula</li>
#         <li>Dioula</li>
#     </ul>
#     <h3>Ethnic groups</h3>
# ...

# %%
# %%HTML
# <h3>Population</h3>
#     <i>The July 2019</i> population estimate by the United Nations was <ins>20,321,378</ins>.
# Out:
# UsageError: %%HTML is a cell magic, but the cell body is empty.
